# %%
from interactive_tree import interactive_tree_model

interactive_tree_model()
# Out:
# interactive(children=(RadioButtons(description='Choose Model', layout=Layout(width='250px'), options=('tree', …
